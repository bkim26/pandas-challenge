# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and setup 
import pandas as pd
import csv

# Read data files into Pandas DataFrame
student_data = "Resources/students_complete.csv"
school_data = "Resources/schools_complete.csv"

student_data = pd.read_csv(student_data)
school_data = pd.read_csv(school_data)

# Combine the data into single data set 
schools_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %%
# Rename column headers 
schools_data_complete = schools_data_complete.rename(columns={"student_name": "Student Name",
                                         "gender": "Gender",
                                         "grade": "Grade",
                                         "school_name": "School Name",
                                         "reading_score": "Reading Score",
                                         "math_score": "Math Score",
                                         "type": "Type",
                                         "size": "Size",
                                         "budget": "Budget"})
schools_data_complete.head()
# Out:
#    Student ID       Student Name Gender Grade        School Name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    Reading Score  Math Score  School ID      Type  Size   Budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
# Calculate the total schools and students 
total_schools = len(schools_data_complete["School Name"].unique())
total_students = schools_data_complete['Student ID'].count()

# Calculate the total budget 
total_budget = school_data["budget"].sum()
total_budget
# Out:
# 24649428

# %%
# Average Scores 
average_math = schools_data_complete["Math Score"].mean()
average_reading = schools_data_complete["Reading Score"].mean()

# %%
# Pass Rate Percentages 
passing_math_count = len(schools_data_complete.loc[schools_data_complete["Math Score"] >= 70]) 
passing_math_percent = passing_math_count / float(total_students) *100
passing_reading_count = len(schools_data_complete.loc[schools_data_complete["Reading Score"] >= 70])
passing_reading_percentage = passing_reading / float(total_students) *100
overall_passing = schools_data_complete[(schools_data_complete["Math Score"] >= 70)
                                        & (schools_data_complete["Reading Score"] >=70)].count()["Student Name"]
overall_passing_percentage = overall_passing / float(total_students) *100
overall_passing_percentage
# Out:
# 65.17232575950983

# %%
district_summary = pd.DataFrame({"Total Schools": [total_schools],
                                   "Total Students": [total_students],
                                   "Total Budget": [total_budget],
                                   "Average Math Score": [average_math],
                                   "Average Reading Score": [average_reading],
                                   "% Passing Math": [passing_math],
                                   "% Passing Reading": [passing_reading],
                                   "% Overall Passing Rate": [overall_passing_percentage]
                                   })

district_summary = district_summary[["Total Schools",
                                     "Total Students",
                                     "Total Budget",
                                     "Average Math Score",
                                     "Average Reading Score",
                                     "% Passing Math",
                                     "% Passing Reading",
                                     "% Overall Passing Rate"]]

district_summary
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0               81.87784       74.980853          85.805463
#
#    % Overall Passing Rate
# 0               65.172326

# %%
district_summary["Total Students"] = district_summary["Total Students"].map("{:,}".format)
district_summary["Total Budget"] = district_summary["Total Budget"].map("${: ,}".format)
district_summary["Average Math Score"] = district_summary["Average Math Score"].map("{:.2f}".format)
district_summary["Average Reading Score"] = district_summary["Average Reading Score"].map("{:.2f}".format)
district_summary["% Passing Math"] = district_summary["% Passing Math"].map('{:.2f}%'.format)
district_summary["% Passing Reading"] = district_summary["% Passing Reading"].map("{:.2f}%".format)
district_summary["% Overall Passing Rate"] = district_summary["% Overall Passing Rate"].map("{:.2f}%".format)

# %%
district_summary
# Out:
#    Total Schools Total Students  Total Budget Average Math Score  \
# 0             15         39,170  $ 24,649,428              78.99
#
#   Average Reading Score % Passing Math % Passing Reading  \
# 0                 81.88         74.98%            85.81%
#
#   % Overall Passing Rate
# 0                 65.17%

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
# Determine the school types using the "school_name" column as the index to find the type 
school_types = school_data.set_index(["school_name"])["type"]

# Calculate total students per school using the data_complete df above in order to retrive the list of schools 
students_per_school = schools_data_complete["School Name"].value_counts()

# Calculate the per school budget using a groupby function to extract data from two separate columns  
budget_per_school = schools_data_complete.groupby(["School Name"]).mean()["Budget"]
per_school_capita = budget_per_school / students_per_school

# Calculate average test score per school
per_school_math_avg = schools_data_complete.groupby(["School Name"]).mean()["Math Score"]
per_school_reading_avg = schools_data_complete.groupby(["School Name"]).mean()["Reading Score"]

# %%
# Calculate total students per school passing math & reading
    # Within schools_data_complete df, grab the "Math Score" column and find scores >= 70 for each school 
    # Within schools_data_complete df, grab the "Reading Score" column and find scores >= 70 for each school 
    # Combined the new filtered df for math and reading and combined them to to get total pass count per school 
    
school_passing_math = schools_data_complete[(schools_data_complete["Math Score"] >= 70)]
school_passing_reading = schools_data_complete[(schools_data_complete["Reading Score"] >= 70)]
school_combined_passing = schools_data_complete[(schools_data_complete["Math Score"] >= 70) 
                                                & (schools_data_complete["Reading Score"] >= 70)]

# %%
# Calculate the pass rates 
school_math_pass_rate = school_passing_math.groupby(["School Name"]).count()["Student Name"] / students_per_school * 100
school_reading_pass_rate = school_passing_reading.groupby(["School Name"]).count()["Student Name"] / students_per_school * 100
overall_passing_rate = school_combined_passing.groupby(["School Name"]).count()["Student Name"] / students_per_school * 100

# %%
# Create pandas dataframe for the results 
school_summary = pd.DataFrame({"School Type": school_types,
                                   "Total Students": students_per_school,
                                   "Total School Budget": budget_per_school,
                                   "Per Student Budget": per_school_capita,
                                   "Average Math Score": per_school_math_avg,
                                   "Average Reading Score": per_school_reading_avg,
                                   "% Passing Math": school_math_pass_rate,
                                   "% Passing Reading": school_reading_pass_rate,
                                   "% Overall Passing": overall_passing_rate})

school_summary = school_summary[["School Type",
                                 "Total Students",
                                 "Total School Budget",
                                 "Per Student Budget",
                                 "Average Math Score",
                                 "Average Reading Score",
                                 "% Passing Math",
                                 "% Passing Reading",
                                 "% Overall Passing"]]

school_summary["Total School Budget"] = school_summary["Total School Budget"].map("${:,.2f}".format)
school_summary["Per Student Budget"] = school_summary["Per Student Budget"].map("${:,.2f}".format)

school_summary.head()
# Out:
#                      School Type  Total Students Total School Budget  \
# Bailey High School      District            4976       $3,124,928.00
# Cabrera High School      Charter            1858       $1,081,356.00
# Figueroa High School    District            2949       $1,884,411.00
# Ford High School        District            2739       $1,763,916.00
# Griffin High School      Charter            1468         $917,500.00
#
#                      Per Student Budget  Average Math Score  \
# Bailey High School              $628.00           77.048432
# Cabrera High School             $582.00           83.061895
# Figueroa High School            $639.00           76.711767
# Ford High School                $644.00           77.102592
# Griffin High School             $625.00           83.351499
#
#                       Average Reading Score  % Passing Math  \
# Bailey High School                81.033963       66.680064
# Cabrera High School               83.975780       94.133477
# ...

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
top_performing = school_summary.sort_values(["% Overall Passing"], ascending=False)
top_performing.head()
# Out:
#                     School Type  Total Students Total School Budget  \
# Cabrera High School     Charter            1858       $1,081,356.00
# Thomas High School      Charter            1635       $1,043,130.00
# Griffin High School     Charter            1468         $917,500.00
# Wilson High School      Charter            2283       $1,319,574.00
# Pena High School        Charter             962         $585,858.00
#
#                     Per Student Budget  Average Math Score  \
# Cabrera High School            $582.00           83.061895
# Thomas High School             $638.00           83.418349
# Griffin High School            $625.00           83.351499
# Wilson High School             $578.00           83.274201
# Pena High School               $609.00           83.839917
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School              83.975780       94.133477          97.039828
# ...

# %%
# top_performing_schools = school_summary.groupby(["% Overall Passing"]["Total Students"].sort_values, ascending=False)

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
bottom_performing = school_summary.sort_values("% Overall Passing", ascending=True)
bottom_performing.head()
# Out:
#                       School Type  Total Students Total School Budget  \
# Rodriguez High School    District            3999       $2,547,363.00
# Figueroa High School     District            2949       $1,884,411.00
# Huang High School        District            2917       $1,910,635.00
# Hernandez High School    District            4635       $3,022,020.00
# Johnson High School      District            4761       $3,094,650.00
#
#                       Per Student Budget  Average Math Score  \
# Rodriguez High School            $637.00           76.842711
# Figueroa High School             $639.00           76.711767
# Huang High School                $655.00           76.629414
# Hernandez High School            $652.00           77.289752
# Johnson High School              $650.00           77.072464
#
#                        Average Reading Score  % Passing Math  \
# Rodriguez High School              80.744686       66.366592
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
# Create a pandas series for each grade 
math_9th = schools_data_complete.loc[schools_data_complete["Grade"] == '9th'].groupby('School Name')['Math Score'].mean()
math_10th = schools_data_complete.loc[schools_data_complete["Grade"] == '10th'].groupby('School Name')['Math Score'].mean()
math_11th = schools_data_complete.loc[schools_data_complete["Grade"] == '11th'].groupby('School Name')['Math Score'].mean()
math_12th = schools_data_complete.loc[schools_data_complete["Grade"] == '12th'].groupby('School Name')['Math Score'].mean()

# %%
# Create variable combined series 
math_scores={"9th Grade": math_9th,
                "10th Grade": math_10th,
                "11th Grade": math_11th,
                "12th Grade": math_12th}

# %%
# Create dataframe for combined series 
grade_math_scores = pd.DataFrame(math_scores)
grade_math_scores
# Out:
#                        9th Grade  10th Grade  11th Grade  12th Grade
# School Name
# Bailey High School     77.083676   76.996772   77.515588   76.492218
# Cabrera High School    83.094697   83.154506   82.765560   83.277487
# Figueroa High School   76.403037   76.539974   76.884344   77.151369
# Ford High School       77.361345   77.672316   76.918058   76.179963
# Griffin High School    82.044010   84.229064   83.842105   83.356164
# Hernandez High School  77.438495   77.337408   77.136029   77.186567
# Holden High School     83.787402   83.429825   85.000000   82.855422
# Huang High School      77.027251   75.908735   76.446602   77.225641
# Johnson High School    77.187857   76.691117   77.491653   76.863248
# Pena High School       83.625455   83.372000   84.328125   84.121547
# Rodriguez High School  76.859966   76.612500   76.395626   77.690748
# Shelton High School    83.420755   82.917411   83.383495   83.778976
# ...

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
# Create a pandas series for each grade 
reading_9th = schools_data_complete.loc[schools_data_complete["Grade"] == '9th'].groupby('School Name')['Reading Score'].mean()
reading_10th = schools_data_complete.loc[schools_data_complete["Grade"] == '10th'].groupby('School Name')['Reading Score'].mean()
reading_11th = schools_data_complete.loc[schools_data_complete["Grade"] == '11th'].groupby('School Name')['Reading Score'].mean()
reading_12th = schools_data_complete.loc[schools_data_complete["Grade"] == '12th'].groupby('School Name')['Reading Score'].mean()

# %%
# Create variable combined series 
reading_scores={"9th Grade": math_9th,
                "10th Grade": math_10th,
                "11th Grade": math_11th,
                "12th Grade": math_12th}

# %%
# Create dataframe for combined series 
grade_reading_scores = pd.DataFrame(math_scores)
grade_reading_scores
# Out:
#                        9th Grade  10th Grade  11th Grade  12th Grade
# School Name
# Bailey High School     77.083676   76.996772   77.515588   76.492218
# Cabrera High School    83.094697   83.154506   82.765560   83.277487
# Figueroa High School   76.403037   76.539974   76.884344   77.151369
# Ford High School       77.361345   77.672316   76.918058   76.179963
# Griffin High School    82.044010   84.229064   83.842105   83.356164
# Hernandez High School  77.438495   77.337408   77.136029   77.186567
# Holden High School     83.787402   83.429825   85.000000   82.855422
# Huang High School      77.027251   75.908735   76.446602   77.225641
# Johnson High School    77.187857   76.691117   77.491653   76.863248
# Pena High School       83.625455   83.372000   84.328125   84.121547
# Rodriguez High School  76.859966   76.612500   76.395626   77.690748
# Shelton High School    83.420755   82.917411   83.383495   83.778976
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# Create the bins in which Data will be held
spending_bins = [0, 585, 630, 645, 675]
group_names = ["<$584", "$585-629", "$630-644","$645-675"]

# %%
# This step makes a copy of my existing school_summary dataframe so it can be used to bin the data 
per_school_spending = school_summary

# %%
# Categorize spending based on the bins
per_school_spending["Spending Ranges (Per Student)"] = pd.cut(per_school_capita, spending_bins, labels=group_names)
per_school_spending.head()
# Out:
#                      School Type  Total Students Total School Budget  \
# Bailey High School      District            4976       $3,124,928.00
# Cabrera High School      Charter            1858       $1,081,356.00
# Figueroa High School    District            2949       $1,884,411.00
# Ford High School        District            2739       $1,763,916.00
# Griffin High School      Charter            1468         $917,500.00
#
#                      Per Student Budget  Average Math Score  \
# Bailey High School              $628.00           77.048432
# Cabrera High School             $582.00           83.061895
# Figueroa High School            $639.00           76.711767
# Ford High School                $644.00           77.102592
# Griffin High School             $625.00           83.351499
#
#                       Average Reading Score  % Passing Math  \
# Bailey High School                81.033963       66.680064
# Cabrera High School               83.975780       94.133477
# ...

# %%
# # Create pandas dataframe for the results 
# school_summary = pd.DataFrame({"School Type": school_types,
#                                    "Total Students": students_per_school,
#                                    "Total School Budget": budget_per_school,
#                                    "Per Student Budget": per_school_capita,
#                                    "Average Math Score": per_school_math_avg,
#                                    "Average Reading Score": per_school_reading_avg,
#                                    "% Passing Math": school_math_pass_rate,
#                                    "% Passing Reading": school_reading_pass_rate,
#                                    "% Overall Passing": overall_passing_rate})

# %%
# Calculations
spending_math_avg = per_school_spending.groupby(["Spending Ranges (Per Student)"]).mean()["Average Math Score"]
spending_reading_avg = per_school_spending.groupby(["Spending Ranges (Per Student)"]).mean()["Average Reading Score"]
spending_math_pass_rate = per_school_spending.groupby(["Spending Ranges (Per Student)"]).mean()["% Passing Math"]
spending_reading_pass_rate = per_school_spending.groupby(["Spending Ranges (Per Student)"]).mean()["% Passing Reading"]
spending_overall_pass_rate = per_school_spending.groupby(["Spending Ranges (Per Student)"]).mean()["% Overall Passing"]

# %%
# Put into dataframe 
spending_summary = pd.DataFrame({"Average Math Score" : spending_math_avg.round(2),
                                 "Average Reading Score": spending_reading_avg.round(2),
                                 "% Passing Math": spending_math_pass_rate.round(2),
                                 "% Passing Reading": spending_reading_pass_rate.round(2),
                                 "% Overall Passing": spending_overall_pass_rate.round(2)})

spending_summary = spending_summary[["Average Math Score", 
                                     "Average Reading Score", 
                                     "% Passing Math", 
                                     "% Passing Reading",
                                     "% Overall Passing"]]

spending_summary
# Out:
#                                Average Math Score  Average Reading Score  \
# Spending Ranges (Per Student)
# <$584                                       83.46                  83.93
# $585-629                                    81.90                  83.16
# $630-644                                    78.52                  81.62
# $645-675                                    77.00                  81.03
#
#                                % Passing Math  % Passing Reading  \
# Spending Ranges (Per Student)
# <$584                                   93.46              96.61
# $585-629                                87.13              92.72
# $630-644                                73.48              84.39
# $645-675                                66.16              81.13
#
#                                % Overall Passing
# Spending Ranges (Per Student)
# <$584                                      90.37
# $585-629                                   81.42
# ...

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# Create the bins
sizing_bins = [0, 1000, 2000, 5000]
group_names = ["Small(<1000)", "Medium(1000-2000)", "Large(2000-5000)"]

# %%
# Make a copy of the dataframe 
per_school_size_scores = school_summary
per_school_size_scores["Scores (Per School Size)"] = pd.cut(students_per_school, sizing_bins, labels=group_names)
per_school_size_scores
# Out:
#                       School Type  Total Students Total School Budget  \
# Bailey High School       District            4976       $3,124,928.00
# Cabrera High School       Charter            1858       $1,081,356.00
# Figueroa High School     District            2949       $1,884,411.00
# Ford High School         District            2739       $1,763,916.00
# Griffin High School       Charter            1468         $917,500.00
# Hernandez High School    District            4635       $3,022,020.00
# Holden High School        Charter             427         $248,087.00
# Huang High School        District            2917       $1,910,635.00
# Johnson High School      District            4761       $3,094,650.00
# Pena High School          Charter             962         $585,858.00
# Rodriguez High School    District            3999       $2,547,363.00
# Shelton High School       Charter            1761       $1,056,600.00
# ...

# %%
per_school_size_scores.sort_values("Total Students", ascending=False)
per_school_size_scores.head()
# Out:
#                      School Type  Total Students Total School Budget  \
# Bailey High School      District            4976       $3,124,928.00
# Cabrera High School      Charter            1858       $1,081,356.00
# Figueroa High School    District            2949       $1,884,411.00
# Ford High School        District            2739       $1,763,916.00
# Griffin High School      Charter            1468         $917,500.00
#
#                      Per Student Budget  Average Math Score  \
# Bailey High School              $628.00           77.048432
# Cabrera High School             $582.00           83.061895
# Figueroa High School            $639.00           76.711767
# Ford High School                $644.00           77.102592
# Griffin High School             $625.00           83.351499
#
#                       Average Reading Score  % Passing Math  \
# Bailey High School                81.033963       66.680064
# Cabrera High School               83.975780       94.133477
# ...

# %%
# Calculations
size_math = per_school_size_scores.groupby(["Scores (Per School Size)"]).mean()["Average Math Score"]
size_reading = per_school_size_scores.groupby(["Scores (Per School Size)"]).mean()["Average Reading Score"]
size_math_prate = per_school_size_scores.groupby(["Scores (Per School Size)"]).mean()["% Passing Math"]
size_reading_prate = per_school_size_scores.groupby(["Scores (Per School Size)"]).mean()["% Passing Reading"]
size_overall_prate = per_school_size_scores.groupby(["Scores (Per School Size)"]).mean()["% Overall Passing"]

# %%
# Put into dataframe 
size_summary = pd.DataFrame({"Average Math Score" : size_math.round(2),
                                 "Average Reading Score": size_reading.round(2),
                                 "% Passing Math": size_math_prate.round(2),
                                 "% Passing Reading": size_reading_prate.round(2),
                                 "% Overall Passing": size_overall_prate.round(2)})

size_summary = size_summary[["Average Math Score", 
                                     "Average Reading Score", 
                                     "% Passing Math", 
                                     "% Passing Reading",
                                     "% Overall Passing"]]

size_summary.head()
# Out:
#                           Average Math Score  Average Reading Score  \
# Scores (Per School Size)
# Small(<1000)                           83.82                  83.93
# Medium(1000-2000)                      83.37                  83.86
# Large(2000-5000)                       77.75                  81.34
#
#                           % Passing Math  % Passing Reading  % Overall Passing
# Scores (Per School Size)
# Small(<1000)                       93.55              96.10              89.88
# Medium(1000-2000)                  93.60              96.79              90.62
# Large(2000-5000)                   69.96              82.77              58.29

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
# Calculations
type_math_scores = school_summary.groupby(["School Type"]).mean()["Average Math Score"]
type_reading_scores = school_summary.groupby(["School Type"]).mean()["Average Reading Score"]
type_passing_math = school_summary.groupby(["School Type"]).mean()["% Passing Math"]
type_passing_reading = school_summary.groupby(["School Type"]).mean()["% Passing Reading"]
type_overall_passing = school_summary.groupby(["School Type"]).mean()["% Overall Passing"]

# %%
# Put into dataframe 
type_summary = pd.DataFrame({"Average Math Score" : type_math_scores.round(2),
                                 "Average Reading Score": type_reading_scores.round(2),
                                 "% Passing Math": type_passing_math.round(2),
                                 "% Passing Reading": type_passing_reading.round(2),
                                 "% Overall Passing": type_overall_passing.round(2)})

type_summary = type_summary[["Average Math Score", 
                                     "Average Reading Score", 
                                     "% Passing Math", 
                                     "% Passing Reading",
                                     "% Overall Passing"]]

type_summary.head()
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter                   83.47                  83.90           93.62
# District                  76.96                  80.97           66.55
#
#              % Passing Reading  % Overall Passing
# School Type
# Charter                  96.59              90.43
# District                 80.80              53.67
